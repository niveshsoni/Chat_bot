# %%
host = "localhost"
port = 5432
database = "vector_db"
user = "vector_user"
password = "vector_pass"

# %%
! pip install psycopg2-binary
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
def get_connection():
    return psycopg2.connect(
        host= host,
        port= port,
        database= database,
        user= user,
        password= password
    )

# %%
import psycopg2
conn = get_connection()
cur = conn.cursor()
cur.execute("SELECT * from playbook_vector_table  WHERE file_id = '1d758b6d-3558-4365-8e7d-c0cab5a8827f'")
records = cur.fetchall()

# %%
records
# Out:
# []
